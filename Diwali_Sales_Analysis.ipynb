# %% [markdown]
# # import  libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # import csv file

# %%
df = pd.read_csv('C:/Users/dmehe/Desktop/DataAnalysis/_projects/Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# # drop unrelated/blank columns

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %% [markdown]
# # check for null values

# %%
df.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# # drop null values

# %%
df.dropna(inplace=True)

# %% [markdown]
# # change data type

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# # rename column

# %%
df.rename(columns= {'Marital_Status':'Married/Unmarried'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28
# 1      1000732       Kartik  P00110942      F     26-35   35
# 2      1001990        Bindu  P00118542      F     26-35   35
# 3      1001425       Sudevi  P00237842      M      0-17   16
# 4      1000588         Joni  P00057942      M     26-35   28
# ...        ...          ...        ...    ...       ...  ...
# 11246  1000695      Manning  P00296942      M     18-25   19
# 11247  1004089  Reichenbach  P00171342      M     26-35   33
# 11248  1001209        Oshin  P00201342      F     36-45   40
# 11249  1004023       Noonan  P00059442      M     36-45   37
# 11250  1002744      Brumley  P00281742      F     18-25   19
#
#        Married/Unmarried           State      Zone       Occupation  \
# 0                      0     Maharashtra   Western       Healthcare
# 1                      1  Andhra Pradesh  Southern             Govt
# ...

# %% [markdown]
# # describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# # use describe() for specific columns

# %%
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Gender

# %% [markdown]
# plotting a bar chart for Gender and it's count

# %%
axis = sns.countplot(x = 'Gender',data = df)

for bars in axis.containers:
    axis.bar_label(bars)

# %% [markdown]
#  plotting a bar chart for gender vs total amount

# %%
sale_amt = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount')

_=sns.barplot(x = 'Gender',y= 'Amount' ,data = sale_amt)

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# ### Age

# %%
plt.figure(figsize=(15,6))
axis = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')
for bars in axis.containers:
    axis.bar_label(bars)

# %% [markdown]
# Total Amount vs Age Group

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
plt.figure(figsize=(15,6))
_=sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age,palette='spring')

# %% [markdown]
# *From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [markdown]
# # Total number of orders from top 10 states

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)[:10]
plt.figure(figsize=(15,7))
axis=sns.barplot(data = sales_state, hue='State',y= 'Orders',palette='hot')
for bars in axis.containers:
    axis.bar_label(bars)

# %% [markdown]
# Total amount/sales from top 10 states

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)[:10]

sns.set(rc={'figure.figsize':(15,5)})
_=sns.barplot(data = sales_state, x = 'State',y= 'Amount',palette='spring')

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status',hue='Marital_Status',palette='viridis')
plt.legend(['Married','Unmarried'])
plt.figure(figsize=(15,5))
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount')

plt.figure(figsize=(15,5))
_=sns.barplot(data = sales, x = 'Marital_Status',y= 'Amount', hue='Gender',palette='hot')

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
plt.figure(figsize=(18,5))
ax = sns.countplot(data = df, x = 'Occupation',palette='magma')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(18,7))
_=sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount',palette='crest')

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT followed by Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
plt.figure(figsize=(23,7))
ax = sns.countplot(data = df, x = 'Product_Category',width=.8,palette='mako')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Clothing & Apparel followed by food and Electronics category*

# %%
sales_cate = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)[:10]

plt.figure(figsize=(20,8))
_=sns.barplot(data = sales_cate, hue = 'Product_Category',y= 'Amount',palette='viridis')
plt.legend(bbox_to_anchor=(1.14,1))

# %% [markdown]
# *From above graphs we can see that the highest amount generate from Food followed by Clothing and Electronics category*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
plt.figure(figsize=(23,8))

ax=sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders',palette='crest')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# from the above graph we see that the highest sell product is P00265242 .

# %% [markdown]
# ## Conclusion:
#
# ###

# %% [markdown]
# *Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category*

# %% [markdown]
#
# complete project on GitHub:

# %% [markdown]
# Thank you!
